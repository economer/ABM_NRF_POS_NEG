# %%
from piplyr import piplyr

# %%
import numpy as np 
from run import run_sim

df_results = run_sim(num_steps=27, flat_benefit_amount=500)

# %%
df_results
# Out:
#         Step  AgentID  basic_benefit  nit_rate  flat_benefit_amount  step  \
# 0          0     8445       0.000000       0.0                  500     0
# 1          0     8334       0.000000       0.0                  500     0
# 2          0     3473       0.000000       0.0                  500     0
# 3          0     9731       0.000000       0.0                  500     0
# 4          0    13059       0.000000       0.0                  500     0
# ...      ...      ...            ...       ...                  ...   ...
# 279995    27     7789    1785.846154       1.0                    0    26
# 279996    27    16926    1785.846154       1.0                    0    26
# 279997    27    16054    1785.846154       1.0                    0    26
# 279998    27     2217    1785.846154       1.0                    0    26
# 279999    27    14178    1785.846154       1.0                    0    26
#
#         unique_id  biweekly_income  net_benefit  income_percentage_change  \
# ...

# %%
df_results[df_results['AgentID']==9731]
# Out:
#         Step  AgentID  basic_benefit  nit_rate  flat_benefit_amount  step  \
# 3          0     9731       0.000000       0.0                  500     0
# 903        1     9731       0.000000       0.0                  500     0
# 1803       2     9731       0.000000       0.0                  500     1
# 2703       3     9731       0.000000       0.0                  500     2
# 3603       4     9731       0.000000       0.0                  500     3
# ...      ...      ...            ...       ...                  ...   ...
# 121503    23     9731    1785.846154       1.0                    0    22
# 122403    24     9731    1785.846154       1.0                    0    23
# 123303    25     9731    1785.846154       1.0                    0    24
# 124203    26     9731    1785.846154       1.0                    0    25
# 125103    27     9731    1785.846154       1.0                    0    26
#
#         unique_id  biweekly_income  net_benefit  income_percentage_change  \
# ...

# %%
# Run R
# ! pip install rpy2
# %load_ext rpy2.ipython

# %%
# %%R
# # load tidyverse
# # install.packages('tidyverse')
# library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# %%R
# library(tidyverse)

# %%
# %R -i df_results

# %%
# %%R
# df_results %>%
# mutate(nrf = pos - neg) %>%
# #filter(step>0) %>%
# count(basic_benefit)
# #group_by(nit_r_factor,`Step`) %>%
# #summarize_at(vars(pos),max)
# Out:
#   basic_benefit      n
# 1         0.000  56000
# 2      1785.846 224000

# %%
# %%R
#
# df_results = df_results %>%
# mutate(nrf = pos - neg) %>%
#  mutate(nit_r_factor = case_when(
#     nit_rate %in% c(0) ~ "Universal",
#     nit_rate %in% c(0.3) ~ "NIT: 0.3",
#     nit_rate %in% c(0.5) ~ "NIT: 0.5",
#     nit_rate %in% c(0.8) ~ "NIT: 0.8",
#    T ~ "Top-Up"
#  ))

# %%
# %%R -w 1200 -h 1000
# # average nrf
# df_results %>%
# #filter(`Base_Benefit`==46432/26) %>%
# mutate(nrf = pos - neg) %>%
# group_by(`Step`,nit_r_factor) %>%
# summarize(mean_nrf = mean(nrf,na.rm=T)) %>%
# ggplot(aes(`Step`,mean_nrf)) +
# geom_line(aes(color=nit_r_factor),size=1) +
# geom_point() +
# #facet_wrap(~nit_r_factor) +
# theme_bw()
# Out:
# `summarise()` has grouped output by 'Step'. You can override using the
# `.groups` argument.
# In addition: Warning message:
# Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_lifecycle_warnings()` to see where this warning was
# generated.

# %%
# %%R -w 800 -h 600
# # median nrf
# df_results %>%
# #filter(`Base_Benefit`==46432/26) %>%
# mutate(nrf = pos - neg) %>%
# group_by(`Step`,nit_r_factor) %>%
# summarize(median_nrf = median(nrf,na.rm=T)) %>%
# ggplot(aes(`Step`,median_nrf)) +
# geom_line(aes(color=nit_r_factor),size=1) +
# geom_point() +
# #facet_wrap(~nit_r_factor) +
# theme_bw()
# Out:
# `summarise()` has grouped output by 'Step'. You can override using the
# `.groups` argument.

# %%
# %%R -w 800 -h 600
# # average pos
# df_results %>%
# #filter(`Base_Benefit`==46432/26) %>%
# mutate(nrf = pos - neg) %>%
# group_by(`Step`,nit_r_factor) %>%
# summarize(mean_pos = mean(pos,na.rm=T)) %>%
# ggplot(aes(`Step`,mean_pos)) +
# geom_line(aes(color=nit_r_factor),size=1) +
# geom_point() +
# #facet_wrap(~nit_r_factor) +
# theme_bw()
# Out:
# `summarise()` has grouped output by 'Step'. You can override using the
# `.groups` argument.

# %%
# %%R -w 800 -h 600
# # average neg
# df_results %>%
# #filter(`Base_Benefit`==46432/26) %>%
# mutate(nrf = pos - neg) %>%
# group_by(`Step`,nit_r_factor) %>%
# summarize(mean_neg = mean(neg,na.rm=T)) %>%
# ggplot(aes(`Step`,mean_neg)) +
# geom_line(aes(color=nit_r_factor),size=1) +
# geom_point() +
# #facet_wrap(~nit_r_factor) +
# theme_bw()
# Out:
# `summarise()` has grouped output by 'Step'. You can override using the
# `.groups` argument.

# %%
# %%R
# install.packages('scales')
# library(scales)
# Out:
# --- Please select a CRAN mirror for use in this session ---
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# The downloaded binary packages are in
# 	/var/folders/34/lfn7_0jd00j1jn_ymrx6t66r0000gn/T//Rtmp2NWxTp/downloaded_packages
# trying URL 'https://muug.ca/mirror/cran/bin/macosx/big-sur-x86_64/contrib/4.3/scales_1.2.1.tgz'
# Content type 'application/octet-stream' length 615923 bytes (601 KB)
# ...
# downloaded 601 KB
#
#
# Attaching package: ‘scales’
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
# The following object is masked from ‘package:readr’:
#
#     col_factor

# %%
# %%R
# df_results %>%
# group_by(nit_r_factor) %>%
# summarize(sum_cost = sum(net_benefit)) %>%
#   mutate(sum_cost = comma(round(sum_cost,3)))
# Out:
# # A tibble: 5 × 2
#   nit_r_factor sum_cost
#   <chr>        <chr>
# 1 NIT: 0.3     1,280,784.533
# 2 NIT: 0.5     1,280,868.692
# 3 NIT: 0.8     1,280,868.702
# 4 Top-Up       34,583,454.954
# 5 Universal    27,000,000.000

# %%
# %%R
# # cost
# df_results %>%
# #filter(`Base_Benefit`==46432/26) %>%
# filter(`Step` %in% c(0,27)) %>%
# ggplot(aes(pos)) +
# geom_histogram(bins=100,aes(color=factor(step)),position="stack") +
# facet_wrap(~nit_r_factor) +
# theme_bw()

# %%
# %%R
# df_mean %>% ggplot(aes(mean_income,mean_nrf)) + geom_line(aes(color=age_sex)) + facet_wrap(~age_sex,scales="free")
